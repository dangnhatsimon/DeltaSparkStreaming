# %%
spark.stop()

# %%
from pyspark.sql.functions import explode, split, trim, lower, expr
from pyspark.sql import SparkSession, DataFrame
from pyspark import SparkConf
from pyspark import SparkContext
import logging
from os.path import abspath
from pathlib import Path
import shutil
from pathlib import Path
from typing import Optional, Union, List, Tuple, Any

# %%
logging.basicConfig(
    format="%(asctime)s - %(levelname)s - %(message)s",
    datefmt="%y-%m-%d %H:%M:%S",
    level=logging.DEBUG
)

# %%
class InvoiceStream:
    def __init__(
        self,
        spark: SparkSession
    ):
        self.spark = spark

    def read_invoices(
        self,
        format: str,
        path: Union[str, Path],
        schema: Union[str, Any]
    ) -> DataFrame:
        if isinstance(path, str):
            path = Path(path).as_posix()
        return (self.spark.readStream
                .format(format)
                .schema(schema)
                .load(path))

    def explode_invoices(self, df: DataFrame) -> DataFrame:
        return (
            df.selectExpr(
                "InvoiceNumber",
                "CreatedTime",
                "StoreID",
                "PosID",
                "CustomerType",
                "PaymentMethod",
                "DeliveryType",
                "DeliveryAddress.City",
                "DeliveryAddress.PinCode",
                "DeliveryAddress.State",
                "explode(InvoiceLineItems) AS LineItem"
            )
        )

    def flatten_invoices(self, df: DataFrame) -> DataFrame:
        return (
            df.withColumn("ItemCode", expr("LineItem.ItemCode"))
            .withColumn("ItemDescription", expr("LineItem.ItemDescription"))
            .withColumn("ItemPrice", expr("LineItem.ItemPrice"))
            .withColumn("ItemQty", expr("LineItem.ItemQty"))
            .withColumn("TotalValue", expr("LineItem.TotalValue"))
            .drop("LineItem")
        )

    def write_invoices(
        self,
        df: DataFrame,
        format: str,
        checkpoint_location: str,
        output_mode: str,
        table: str
    ):
        return (
            df.writeStream
            .format(format)
            .option("checkpointLocation", checkpoint_location)
            .outputMode(output_mode)
            .toTable(table)
        )

# %%
if __name__ == "__main__":
    table_name = "invoice_line_items"
    schema = """
        InvoiceNumber string,
        CreatedTime bigint,
        StoreID string,
        PosID string,
        CashierID string,
        CustomerType string,
        CustomerCardNo string,
        TotalAmount double,
        NumberOfItems bigint,
        PaymentMethod string,
        TaxableAmount double,
        CGST double,
        SGST double,
        CESS double,
        DeliveryType string,
        DeliveryAddress struct<
            AddressLine string,
            City string,
            ContactNumber string,
            PinCode string,
            State string
        >,
        InvoiceLineItems array<
            struct<
                ItemCode string,
                ItemDescription string,
                ItemPrice double,
                ItemQty bigint,
                TotalValue double
            >
        >
    """
    spark = (
        SparkSession.builder
        .appName("InvoicesStream")
        .enableHiveSupport()
        .getOrCreate()
    )
    invoices_stream = InvoiceStream(spark)
    invoices_df = invoices_stream.read_invoices(
        format="json",
        path="/opt/spark/datasets/invoices/*.json",
        schema=schema
    )
    exploded_df = invoices_stream.explode_invoices(invoices_df)
    flatten_df = invoices_stream.flatten_invoices(exploded_df)
    squery = invoices_stream.write_invoices(
        df=flatten_df,
        format="delta",
        checkpoint_location="/opt/spark/datasets/checkpoint/invoices",
        output_mode="append",
        table=table_name
    )
# Out:
# 25-05-17 10:16:38 - DEBUG - Command to send: r
# u
# SparkConf
# rj
# e
#
# 25-05-17 10:16:38 - DEBUG - Answer received: !ycorg.apache.spark.SparkConf
# 25-05-17 10:16:38 - DEBUG - Command to send: i
# org.apache.spark.SparkConf
# bTrue
# e
#
# 25-05-17 10:16:38 - DEBUG - Answer received: !yro52
# 25-05-17 10:16:38 - DEBUG - Command to send: c
# o52
# set
# sspark.app.name
# sInvoicesStream
# e
#
# 25-05-17 10:16:38 - DEBUG - Answer received: !yro53
# 25-05-17 10:16:38 - DEBUG - Command to send: c
# o52
# set
# sspark.sql.catalogImplementation
# shive
# e
#
# 25-05-17 10:16:38 - DEBUG - Answer received: !yro54
# 25-05-17 10:16:38 - DEBUG - Command to send: c
# o52
# get
# sspark.executor.allowSparkContext
# sfalse
# e
#
# 25-05-17 10:16:38 - DEBUG - Answer received: !ysfalse
# 25-05-17 10:16:38 - DEBUG - Command to send: c
# o52
# contains
# sspark.serializer.objectStreamReset
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# set
# sspark.serializer.objectStreamReset
# s100
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro55
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.rdd.compress
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# set
# sspark.rdd.compress
# sTrue
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro56
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.master
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.app.name
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.master
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# get
# sspark.master
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark://delta-streaming-spark-master:7077
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.app.name
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# get
# sspark.app.name
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysInvoicesStream
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# contains
# sspark.home
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o52
# getAll
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yto57
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i0
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro58
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o58
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.eventLog.enabled
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o58
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ystrue
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro59
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o59
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.executor.memory
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o59
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys2g
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro60
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o60
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.hadoop.fs.s3a.aws.credentials.provider
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o60
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysorg.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i3
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro61
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o61
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.app.submitTime
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o61
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys1747476966145
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i4
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro62
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o62
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.driver.memoryOverheadFactor
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o62
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys0.1
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i5
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro63
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o63
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.executor.cores
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o63
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys4
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i6
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro64
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o64
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.serializer
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o64
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysorg.apache.spark.serializer.KryoSerializer
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i7
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro65
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o65
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.hadoop.fs.s3a.impl
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o65
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysorg.apache.hadoop.fs.s3a.S3AFileSystem
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i8
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro66
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o66
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.history.fs.logDirectory
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o66
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/opt/spark/spark-events
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i9
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro67
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o67
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.hadoop.fs.s3a.access.key
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o67
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysaccess_key
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i10
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro68
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o68
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.hadoop.fs.s3a.secret.key
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o68
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yssecret_key
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i11
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro69
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o69
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.app.name
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o69
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysInvoicesStream
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i12
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro70
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o70
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.log.level
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o70
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysERROR
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i13
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro71
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o71
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.sql.catalogImplementation
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o71
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yshive
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i14
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro72
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o72
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.sql.extensions
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o72
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysio.delta.sql.DeltaSparkSessionExtension
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i15
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro73
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o73
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.rdd.compress
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o73
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysTrue
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i16
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro74
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o74
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.serializer.objectStreamReset
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o74
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys100
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i17
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro75
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o75
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.master
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o75
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark://delta-streaming-spark-master:7077
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i18
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro76
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o76
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.submit.pyFiles
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o76
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i19
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro77
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o77
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.submit.deployMode
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o77
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysclient
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i20
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro78
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o78
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.ui.showConsoleProgress
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o78
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ystrue
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i21
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro79
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o79
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.sql.warehouse.dir
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o79
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/opt/spark/warehouse
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i22
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro80
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o80
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.sql.catalog.spark_catalog
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o80
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysorg.apache.spark.sql.delta.catalog.DeltaCatalog
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# g
# o57
# i23
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro81
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o81
# _1
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysspark.eventLog.dir
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o81
# _2
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/opt/spark/spark-events
# 25-05-17 10:16:39 - DEBUG - Command to send: a
# e
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi24
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# JavaSparkContext
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.api.java.JavaSparkContext
# 25-05-17 10:16:39 - DEBUG - Command to send: i
# org.apache.spark.api.java.JavaSparkContext
# ro52
# e
#
# Setting Spark log level to "ERROR".
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o53
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o54
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o55
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o56
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o58
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o59
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o61
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o62
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o63
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o64
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o65
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o66
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o67
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o68
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o69
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o70
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: m
# d
# o57
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro82
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o82
# sc
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro83
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o83
# conf
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro84
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# PythonAccumulatorV2
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonAccumulatorV2
# 25-05-17 10:16:39 - DEBUG - Command to send: i
# org.apache.spark.api.python.PythonAccumulatorV2
# s127.0.0.1
# i34573
# seb40cc4ad6031e4bebc02fdb54baf51b10292ea99a3fce2966925a23ab88cf92
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro85
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o82
# sc
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro86
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o86
# register
# ro85
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# isEncryptionEnabled
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# isEncryptionEnabled
# ro82
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getPythonAuthSocketTimeout
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getPythonAuthSocketTimeout
# ro82
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yL15
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getSparkBufferSize
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getSparkBufferSize
# ro82
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yi65536
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark.SparkFiles
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.SparkFiles
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.SparkFiles
# getRootDirectory
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.SparkFiles
# getRootDirectory
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/tmp/spark-7c871663-1bcc-4921-8399-fa5ccd3a465c/userFiles-fab18371-88fd-4a64-9eb9-2f7896cbdca9
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o84
# get
# sspark.submit.pyFiles
# s
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark.util
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark.util.Utils
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.util.Utils
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.util.Utils
# getLocalDir
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o82
# sc
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro87
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o87
# conf
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro88
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.util.Utils
# getLocalDir
# ro88
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/tmp/spark-7c871663-1bcc-4921-8399-fa5ccd3a465c
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark.util
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yp
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# org.apache.spark.util.Utils
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.util.Utils
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.util.Utils
# createTempDir
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.util.Utils
# createTempDir
# s/tmp/spark-7c871663-1bcc-4921-8399-fa5ccd3a465c
# spyspark
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro89
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o89
# getAbsolutePath
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ys/tmp/spark-7c871663-1bcc-4921-8399-fa5ccd3a465c/pyspark-f64641b3-33cc-4c1f-8827-0dbe8829b914
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o84
# get
# sspark.python.profile
# sfalse
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o84
# get
# sspark.python.profile.memory
# sfalse
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ysfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# getDefaultSession
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# getDefaultSession
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro90
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o90
# isDefined
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ybfalse
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o82
# sc
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro91
# 25-05-17 10:16:39 - DEBUG - Command to send: i
# java.util.HashMap
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yao92
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o92
# put
# sspark.app.name
# sInvoicesStream
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yn
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o92
# put
# sspark.sql.catalogImplementation
# shive
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yn
# 25-05-17 10:16:39 - DEBUG - Command to send: i
# org.apache.spark.sql.SparkSession
# ro91
# ro92
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yro93
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setDefaultSession
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# setDefaultSession
# ro93
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:39 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# setActiveSession
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !ym
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# setActiveSession
# ro93
# e
#
# 25-05-17 10:16:39 - DEBUG - Answer received: !yv
# 25-05-17 10:16:39 - DEBUG - Command to send: c
# o93
# readStream
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro94
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o94
# format
# sjson
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro95
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# getActiveSession
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ym
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# getActiveSession
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro96
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o96
# isDefined
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# u
# SparkSession
# rj
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession
# getActiveSession
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ym
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# z:org.apache.spark.sql.SparkSession
# getActiveSession
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro97
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o97
# get
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro98
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# u
# SparkSession$
# rj
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !ycorg.apache.spark.sql.SparkSession$
# 25-05-17 10:16:40 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.SparkSession$
# MODULE$
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro99
# 25-05-17 10:16:40 - DEBUG - Command to send: m
# d
# o92
# e
#
# 25-05-17 10:16:40 - DEBUG - Command to send: i
# java.util.HashMap
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yv
# 25-05-17 10:16:40 - DEBUG - Answer received: !yao100
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o99
# applyModifiableSettings
# ro98
# ro100
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yv
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o95
# schema
# s\n        InvoiceNumber string,\n        CreatedTime bigint,\n        StoreID string,\n        PosID string,\n        CashierID string,\n        CustomerType string,\n        CustomerCardNo string,\n        TotalAmount double,\n        NumberOfItems bigint,\n        PaymentMethod string,\n        TaxableAmount double,\n        CGST double,\n        SGST double,\n        CESS double,\n        DeliveryType string,\n        DeliveryAddress struct<\n            AddressLine string,\n            City string,\n            ContactNumber string,\n            PinCode string,\n            State string\n        >,\n        InvoiceLineItems array<\n            struct<\n                ItemCode string,\n                ItemDescription string,\n                ItemPrice double,\n                ItemQty bigint,\n                TotalValue double\n            >\n        >\n
# e
#
# 25-05-17 10:16:40 - DEBUG - Answer received: !yro101
# 25-05-17 10:16:40 - DEBUG - Command to send: c
# o101
# load
# s/opt/spark/datasets/invoices/*.json
# e
#
# 25-05-17 10:16:41 - DEBUG - Command to send: m
# d
# o100
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yv
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro102
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# toSeq
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ym
# 25-05-17 10:16:41 - DEBUG - Command to send: i
# java.util.ArrayList
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ylo103
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sInvoiceNumber
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sCreatedTime
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sStoreID
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sPosID
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sCustomerType
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sPaymentMethod
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sDeliveryType
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sDeliveryAddress.City
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sDeliveryAddress.PinCode
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sDeliveryAddress.State
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o103
# add
# sexplode(InvoiceLineItems) AS LineItem
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# toSeq
# ro103
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro104
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o102
# selectExpr
# ro104
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro105
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# expr
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ym
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# expr
# sLineItem.ItemCode
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro106
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o105
# withColumn
# sItemCode
# ro106
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro107
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 25-05-17 10:16:41 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# expr
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !ym
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# expr
# sLineItem.ItemDescription
# e
#
# 25-05-17 10:16:41 - DEBUG - Answer received: !yro108
# 25-05-17 10:16:41 - DEBUG - Command to send: c
# o107
# withColumn
# sItemDescription
# ro108
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro109
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# expr
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ym
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# expr
# sLineItem.ItemPrice
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro110
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o109
# withColumn
# sItemPrice
# ro110
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro111
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# expr
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ym
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# expr
# sLineItem.ItemQty
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro112
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o111
# withColumn
# sItemQty
# ro112
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro113
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# u
# functions
# rj
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ycorg.apache.spark.sql.functions
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# m
# org.apache.spark.sql.functions
# expr
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ym
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# z:org.apache.spark.sql.functions
# expr
# sLineItem.TotalValue
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro114
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o113
# withColumn
# sTotalValue
# ro114
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro115
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# u
# PythonUtils
# rj
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ycorg.apache.spark.api.python.PythonUtils
# 25-05-17 10:16:42 - DEBUG - Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# toSeq
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ym
# 25-05-17 10:16:42 - DEBUG - Command to send: i
# java.util.ArrayList
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ylo116
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o116
# add
# sLineItem
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !ybtrue
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# toSeq
# ro116
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro117
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o115
# drop
# ro117
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro118
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o118
# writeStream
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro119
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o119
# format
# sdelta
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro120
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o120
# option
# scheckpointLocation
# s/opt/spark/datasets/checkpoint/invoices
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro121
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o121
# outputMode
# sappend
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yro122
# 25-05-17 10:16:42 - DEBUG - Command to send: c
# o122
# toTable
# sinvoice_line_items
# e
#
# 25-05-17 10:16:42 - DEBUG - Command to send: m
# d
# o103
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yv
# 25-05-17 10:16:42 - DEBUG - Command to send: m
# d
# o116
# e
#
# 25-05-17 10:16:42 - DEBUG - Answer received: !yv
# 25-05-17 10:16:51 - DEBUG - Answer received: !yro123

# %%
spark.read.table(table_name).show()
# Out:
# 25-05-17 10:20:22 - DEBUG - Command to send: c
# o93
# read
# e
#
# 25-05-17 10:20:22 - DEBUG - Answer received: !yro132
# 25-05-17 10:20:22 - DEBUG - Command to send: c
# o132
# table
# sinvoice_line_items
# e
#
# 25-05-17 10:20:22 - DEBUG - Answer received: !yro133
# 25-05-17 10:20:22 - DEBUG - Command to send: c
# o133
# showString
# i20
# i20
# bFalse
# e
#
# 25-05-17 10:20:26 - DEBUG - Answer received: !ys+-------------+-------------+-------+------+------------+-------------+-------------+---------+-------+--------------+--------+-------------------+---------+-------+----------+\n|InvoiceNumber|  CreatedTime|StoreID| PosID|CustomerType|PaymentMethod| DeliveryType|     City|PinCode|         State|ItemCode|    ItemDescription|ItemPrice|ItemQty|TotalValue|\n+-------------+-------------+-------+------+------------+-------------+-------------+---------+-------+--------------+--------+-------------------+---------+-------+----------+\n|     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     458|         Wine glass|   1644.0|      2|    3288.0|\n|     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     283|     Portable Lamps|   2236.0|      1|    2236.0|\n|     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     498|     Carving knifes|   1424.0|      2|    2848.0|\n|     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     523|     Oil-lamp clock|   1371.0|      2|    2742.0|\n|     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     413|          Slipcover|   1896.0|      1|    1896.0|\n|     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     483|Teacups and saucers|   1781.0|      1|    1781.0|\n|     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     583|   Tab Top Curtains|   1329.0|      1|    1329.0|\n|     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     558|      Balloon clock|   1633.0|      2|    3266.0|\n|     93647513|1595688902254|STR8513|POS881|    NONPRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     258|             Closet|   1687.0|      2|    3374.0|\n|      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     288|              Hutch|   1812.0|      2|    3624.0|\n|      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     558|      Balloon clock|   1633.0|      1|    1633.0|\n|      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     658|            Chinois|    567.0|      1|     567.0|\n|      4888607|1595688903258|STR2629|POS172|    NONPRIME|         CASH|HOME-DELIVERY|   Ratlam| 925281|Madhya Pradesh|     208|         Canopy bed|    508.0|      1|     508.0|\n|      4888607|1595688903258|STR2629|POS172|    NONPRIME|         CASH|HOME-DELIVERY|   Ratlam| 925281|Madhya Pradesh|     408|         Confidante|   1242.0|      1|    1242.0|\n|     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     353|           Recliner|   1585.0|      2|    3170.0|\n|     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     488|        Bread knife|   1077.0|      2|    2154.0|\n|     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     408|         Confidante|   1242.0|      1|    1242.0|\n|     89101510|1595688904763|STR6347|POS994|       PRIME|         CASH|     TAKEAWAY|     NULL|   NULL|          NULL|     493|       Boning knife|    513.0|      1|     513.0|\n|     89101510|1595688904763|STR6347|POS994|       PRIME|         CASH|     TAKEAWAY|     NULL|   NULL|          NULL|     468|          Lunch box|   1467.0|      1|    1467.0|\n|     89101510|1595688904763|STR6347 ...
# +-------------+-------------+-------+------+------------+-------------+-------------+---------+-------+--------------+--------+-------------------+---------+-------+----------+
# |InvoiceNumber|  CreatedTime|StoreID| PosID|CustomerType|PaymentMethod| DeliveryType|     City|PinCode|         State|ItemCode|    ItemDescription|ItemPrice|ItemQty|TotalValue|
# +-------------+-------------+-------+------+------------+-------------+-------------+---------+-------+--------------+--------+-------------------+---------+-------+----------+
# |     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     458|         Wine glass|   1644.0|      2|    3288.0|
# |     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     283|     Portable Lamps|   2236.0|      1|    2236.0|
# |     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     498|     Carving knifes|   1424.0|      2|    2848.0|
# |     51402977|1595688900348|STR7188|POS956|       PRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     523|     Oil-lamp clock|   1371.0|      2|    2742.0|
# |     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     413|          Slipcover|   1896.0|      1|    1896.0|
# |     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     483|Teacups and saucers|   1781.0|      1|    1781.0|
# |     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     583|   Tab Top Curtains|   1329.0|      1|    1329.0|
# |     91372973|1595688901219|STR8513|POS163|       PRIME|         CARD|HOME-DELIVERY|Shivapuri| 561012|Madhya Pradesh|     558|      Balloon clock|   1633.0|      2|    3266.0|
# |     93647513|1595688902254|STR8513|POS881|    NONPRIME|         CARD|     TAKEAWAY|     NULL|   NULL|          NULL|     258|             Closet|   1687.0|      2|    3374.0|
# |      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     288|              Hutch|   1812.0|      2|    3624.0|
# |      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     558|      Balloon clock|   1633.0|      1|    1633.0|
# |      8320594|1595688902254|STR7188|POS825|       PRIME|         CASH|HOME-DELIVERY|    Dehri| 637308|         Bihar|     658|            Chinois|    567.0|      1|     567.0|
# |      4888607|1595688903258|STR2629|POS172|    NONPRIME|         CASH|HOME-DELIVERY|   Ratlam| 925281|Madhya Pradesh|     208|         Canopy bed|    508.0|      1|     508.0|
# |      4888607|1595688903258|STR2629|POS172|    NONPRIME|         CASH|HOME-DELIVERY|   Ratlam| 925281|Madhya Pradesh|     408|         Confidante|   1242.0|      1|    1242.0|
# |     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     353|           Recliner|   1585.0|      2|    3170.0|
# |     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     488|        Bread knife|   1077.0|      2|    2154.0|
# |     99794761|1595688903258|STR6347|POS333|    NONPRIME|         CARD|HOME-DELIVERY|Champdani| 680616|   West Bengal|     408|         Confidante|   1242.0|      1|    1242.0|
# |     89101510|1595688904763|STR6347|POS994|       PRIME|         CASH|     TAKEAWAY|     NULL|   NULL|          NULL|     493|       Boning knife|    513.0|      1|     513.0|
# |     89101510|1595688904763|STR6347|POS994|       PRIME|         CASH|     TAKEAWAY|     NULL|   NULL|          NULL|     468|          Lunch box|   1467.0|      1|    1467.0|
# |     89101510|1595688904763|STR6347|POS994|       PRIME|         CASH|     TAKEAWAY|     NULL|   NULL|          NULL|     348|         Navy chair|   1998.0|      1|    1998.0|
# +-------------+-------------+-------+------+------------+-------------+-------------+---------+-------+--------------+--------+-------------------+---------+-------+----------+
# only showing top 20 rows
